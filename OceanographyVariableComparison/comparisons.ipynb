# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import math


chl_df = pd.read_excel("./data/chlorophyll readings report CAR-2025-500 (2025-09-29).xlsx", header=2)
cols = ["Bottle", "Depth (m)", "Chlorophyll-a (μg)", "Fluorescence from ctd"]
chl_subdf = chl_df.loc[:, cols].sort_values("Depth (m)").rename(columns={"Depth (m)":"depth","Chlorophyll-a (μg)":"lab", "Fluorescence from ctd":"ctd"})

m0 = min(chl_subdf["ctd"].min(), chl_subdf["lab"].min())
m1 = max(chl_subdf["ctd"].max(), chl_subdf["lab"].max())
x = y = np.arange(m0,m1,0.1)

fig, axs = plt.subplots(1,2, figsize=(15, 5))
ax0, ax1 = axs
ax0.scatter(data=chl_subdf, x="lab", y="ctd", marker="+")
ax0.plot(x,y, "--r")
ax0.text(2.5,2.25, "x=y")
ax0.set_xlabel('from Lab')
ax0.set_ylabel('from CTD')
ax0.set_title('Scatter plot of lab vs CTD results (fluorescence)')

ax1.plot(chl_subdf["depth"], chl_subdf["ctd"], label="ctd")
ax1.plot(chl_subdf["depth"], chl_subdf["lab"], label="lab")
ax1.set_xlabel('Depth (m)')
ax1.set_ylabel('chlor')
ax1.set_title('Line plot of lab and CTD fluorescence')
ax1.legend()
plt.show()

# %%
o2_df = pd.read_excel("./data/oxygen readings report CAR-2025-500 (2025-09-29).xlsx", header=2)
cols = ["Bottle", "Depth (m)", "Oxygen concentration (ml/L)", "Value from ctd"]
o2_subdf = o2_df.loc[:, cols].sort_values("Depth (m)").rename(columns={"Depth (m)":"depth","Oxygen concentration (ml/L)":"lab", "Value from ctd":"ctd"})
# o2_subdf = o2_subdf.groupby("Bottle").agg("mean").sort_values("Depth (m)")
# o2_subdf

m0 = min(o2_subdf["ctd"].min(), o2_subdf["lab"].min())
m1 = max(o2_subdf["ctd"].max(), o2_subdf["lab"].max())
x = y = np.arange(m0,m1,0.1)

fig, axs = plt.subplots(1,2, figsize=(15, 5))
ax0, ax1 = axs
ax0.scatter(data=o2_subdf, x="lab", y="ctd", marker="+")
ax0.plot(x,y, "--r")
ax0.text(2.5,3.5, "x=y")
ax0.set_xlabel('from Lab')
ax0.set_ylabel('from CTD')
ax0.set_title('Scatter plot of lab vs CTD results (oxygen)')

ax1.plot(o2_subdf["depth"], o2_subdf["ctd"], label="ctd")
ax1.plot(o2_subdf["depth"], o2_subdf["lab"], label="lab")
ax1.set_xlabel('Depth (m)')
ax1.set_ylabel('o2 conc')
ax1.set_title('Line plot of lab and CTD oxygen')
ax1.legend()
plt.show()

# %%
sal_df = pd.read_excel("./data/salinity readings report CAR-2025-500 (2025-10-02).xlsx", header=2)
cols = ["Bottle", "Depth (m)", "Calculated salinity", "Value from ctd"]
sal_subdf = sal_df.loc[:, cols].sort_values("Depth (m)").rename(columns={"Depth (m)":"depth","Calculated salinity":"lab", "Value from ctd":"ctd"})
# sal_subdf = sal_subdf.groupby("Bottle").agg("mean").sort_values("Depth (m)")
# sal_subdf
#
m0 = min(sal_subdf["ctd"].min(), sal_subdf["lab"].min())
m1 = max(sal_subdf["ctd"].max(), sal_subdf["lab"].max())
x = y = np.arange(m0,m1,0.1)

fig, axs = plt.subplots(1,2, figsize=(15, 5))
ax0, ax1 = axs
ax0.scatter(data=sal_subdf, x="lab", y="ctd", marker="+")
ax0.plot(x,y, "--r")
ax0.text(31,33, "x=y")
ax0.set_xlabel('from Lab')
ax0.set_ylabel('from CTD')
ax0.set_title('Scatter plot of lab vs CTD results (salinity)')

ax1.plot(sal_subdf["depth"], sal_subdf["ctd"], label="ctd")
ax1.plot(sal_subdf["depth"], sal_subdf["lab"], label="lab")
ax1.set_xlabel('Depth (m)')
ax1.set_ylabel('sal')
ax1.set_title('Line plot of lab and CTD salinity')
ax1.legend()
plt.show()
